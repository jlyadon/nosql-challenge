# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with 'mongoimport --type json -d uk_food -c establishments --drop --jsonArray Resources\establishments.json'

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'classdb',
#  'config',
#  'epa',
#  'fruitsDB',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collections()

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
db.establishments.find_one()
# Out:
# {'_id': ObjectId('66b9409f8a69a4e52d42ceb4'),
#  'FHRSID': 452092,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000040614',
#  'BusinessName': 'Walmer and Kingsdown Golf Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'The Leas',
#  'AddressLine2': 'Kingsdown',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT14 8EP',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2019-09-10T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': None,
#   'Structural': None,
#   'ConfidenceInManagement': None},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.40325689315796', 'latitude': '51.1787300109863'},
#  'RightToReply': '',
#  'Distance': 4587.793855801259,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/452092'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavors = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(penang_flavors)
# Out:
# InsertOneResult(ObjectId('66b940a98eece0e8ec7379d8'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
establishments.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('66b940a98eece0e8ec7379d8'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
list(
    establishments.find(
        {'BusinessType':'Restaurant/Cafe/Canteen'},{'BusinessTypeID':1,'BusinessType':1}
    )
)
# Out:
# [{'_id': ObjectId('66b9409f8a69a4e52d42ceb5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cebc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cebd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cec0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cec1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cec6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cec7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cecb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cecc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cece'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42ced0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42ced1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42ced6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42ced7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42ceda'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cee1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cee7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cee8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42ceeb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42ceec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42ceee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cef3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cef4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cef5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cef6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cefa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cefb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cefc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cefe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf02'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf03'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf07'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf0b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf0d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf0f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf21'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf22'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf23'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf26'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf27'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf29'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf2e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf36'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf38'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf39'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf3e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf3f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf41'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf43'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf48'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf4f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf52'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf55'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf58'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf5c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf5d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf5e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf61'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf67'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf6f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf70'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf76'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf77'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf7c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf7e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf7f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf8e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf8f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf92'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf93'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cf9e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfa1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfa3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfa5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfb0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfb2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfb3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfb5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfb8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfc4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfc7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfcd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfce'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfd0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfd5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfdc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfde'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfeb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cfef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cff2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cff6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cff8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cff9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cffa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42cffd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d000'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d001'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d002'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d003'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d004'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d007'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d008'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d009'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d00b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d012'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d015'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d01b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d020'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d022'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d023'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d025'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d02d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d02f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d031'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d032'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d033'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d036'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d039'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d03e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d040'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d041'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d04d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d04e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d050'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d054'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d058'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d05c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d05e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d061'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d063'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d065'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d06b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d070'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d07c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d07d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d080'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d089'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d08b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d092'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d095'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d096'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0a3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0b3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0c6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0d6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0d7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0da'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0dc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0e0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d0fd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d108'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d117'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d11c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d12a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d12b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d12c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d134'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d145'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d149'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d14f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d150'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d159'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d15d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d161'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d163'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d164'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d168'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d16b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d174'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d175'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d179'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d180'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d184'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d18d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d18f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d195'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d196'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1a4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1a7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1aa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1ac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1b2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1c1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1c7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1c9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1cc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1cf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1d5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1e5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1e9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1ee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1f7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1f8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1f9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1fb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1fc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d1ff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d200'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d203'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d208'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d20c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d20f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d211'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d212'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d214'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d216'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d219'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d223'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d224'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d226'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d229'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d22c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d22f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d232'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d236'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d237'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d238'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d23b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d23c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d23f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d240'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d242'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d244'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d248'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d24b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d24c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d250'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d254'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d255'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d25a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d25e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d263'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d268'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d26c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d26e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d26f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d270'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d271'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d276'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d27c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d27e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d27f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d283'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d284'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d285'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d287'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d289'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d28f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d291'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d292'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d293'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d29f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2a2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2a3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2a5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2a9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2ad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2ae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2af'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2b0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2b3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2b5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2b6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2bc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2c0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2c7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2c9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2cf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2da'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2e6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2f1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2f6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2f7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2fb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d2ff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d311'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d319'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d31e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d31f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d321'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d323'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d32c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d330'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d331'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d332'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d333'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d334'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d335'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d338'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d339'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d33a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d33b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d33d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d341'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d34c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d34f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d352'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d353'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d355'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d356'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d357'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d359'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d35a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d35c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d35d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d360'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d361'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d366'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d367'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d36d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d36e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d36f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d370'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d376'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d379'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d37a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d37d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d386'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d387'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d389'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d38a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d38c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d38d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d397'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d39b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d39d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3a3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3a6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3a9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3aa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3ac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3ae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3b6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3c0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3c4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3c8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3cb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3ce'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3d2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3d3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3d6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3de'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3e0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3e3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3e5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3eb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3f2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3f7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3f8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d3fc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d400'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d404'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d407'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d40b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d40d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d40e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d410'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d411'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d412'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d413'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d415'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d416'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d418'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d419'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d41c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d41d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d41e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d41f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d422'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d424'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d425'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d427'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d428'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d429'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d42a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d42b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d42d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d42e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d431'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d434'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d43b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d43c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d43e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d440'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d445'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d446'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d447'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d44e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d44f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d450'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d453'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d458'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d459'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d45e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d463'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d46e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d475'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d480'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d486'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d488'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d48b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d48d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42d496'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42daf6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42daf7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42daf8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dafb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db01'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db13'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db14'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db21'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db22'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db26'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db34'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db38'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db3c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db49'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db4c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db50'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db58'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db5d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db6f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db70'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db74'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db75'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db76'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db7c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db7e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db89'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db8f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db93'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42db99'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dba0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dba8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbb8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbc1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbc7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbd2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbd7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbd9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbdf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbe7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbeb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbf3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbf5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbf8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbfd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dbfe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc03'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc29'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc33'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc34'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc36'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc39'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc3b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc3c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc40'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc45'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc47'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc55'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc56'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc59'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc5a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc5b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc5f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc61'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc65'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc67'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc68'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc69'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc6b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc6c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc6d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc6f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc72'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc73'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc74'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc76'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc7d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc7f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc8d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc8e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc90'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc93'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc94'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc9a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc9d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc9e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dc9f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dca2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dca7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dca8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcb7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcb8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcbb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcbe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcbf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcc0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcc6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcc7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcc8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcc9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dccd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcd2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcd3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcd7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcd9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcda'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcdb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcde'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dce1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dce4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dceb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcf1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcf2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcf3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcf6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcf9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcfb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dcfe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd01'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd02'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd04'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd05'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd06'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd0a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd0b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd0d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('66b9409f8a69a4e52d42dd0e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  ...]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({'BusinessName':'Penang Flavours'},{'$set':{'BusinessTypeID':1}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
establishments.find_one({'BusinessName':'Penang Flavours'},{'BusinessTypeID':1,'BusinessName':1})
# Out:
# {'_id': ObjectId('66b940a98eece0e8ec7379d8'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessTypeID': 1}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName':'Dover'})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName':'Dover'})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName':'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('66b9409f8a69a4e52d42d196'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
# I can't get this cell to work. I'm just going to skip it, since it doesn't come up in the last part of the project.

# establishments.update_many({}, [ {'$convert':{
#      {'latitude' : {'$toDouble': '$latitude'}},\
#      {'longitude': {'$toDouble': '$longitude'}}
# }} ])

# establishments.update_many({},[
#     {'$toDecimal',{'geocode':'latitude'}},
#     {'$toDecimal',{'geocode':'longitude'}}
# ])

# establishments.update_many({},[{'$set':{{'geocode':'latitude'}:{'$toDouble':'$latitude'}}}])
# establishments.update_many({},[{'$set':{{'geocode':'longitude'}:{'$toDouble':'$longitude'}}}])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 14
#       1 # Change the data type from String to Decimal for longitude and latitude
#       2 # HERE'S THE PROBLEM: LAT AND LONG ARE INSIDE ANOTHER FIELD
#       3
#    (...)
#      11 #     {'$toDecimal',{'geocode':'longitude'}}
#      12 # ])
# ---> 14 establishments.update_many({},[{'$set':{{'geocode':'latitude'}:{'$toDouble':'$latitude'}}}])
#      15 establishments.update_many({},[{'$set':{{'geocode':'longitude'}:{'$toDouble':'$longitude'}}}])
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ {'$set':{
     'RatingValue' : {'$toInt': '$RatingValue'},\
}} ])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
establishments.count_documents(
    {
        # 'latitude':{'$type':'decimal'},
        # 'longitude':{'$type':'decimal'},  Never could get these two to work
        'RatingValue':{'$type':'int'}
    }
)
# Out:
# 34694
